# %% [markdown]
# <a href="https://colab.research.google.com/github/zzhining/ml_basic/blob/main/apriori_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

dt = sns.load_dataset('titanic')
dt = dt[["class", "sex", "age", "alive"]]
dt = dt.dropna(axis=0)
dt.head()
# Out:
#    class     sex   age alive
# 0  Third    male  22.0    no
# 1  First  female  38.0   yes
# 2  Third  female  26.0   yes
# 3  First  female  35.0   yes
# 4  Third    male  35.0    no

# %%
# 나이 범주화
child_idx = dt.age < 20
adult_idx = (dt.age >= 20) & (dt.age < 60)
old_idx = dt.age >= 60

dt.loc[child_idx, "age"] = "child"
dt.loc[adult_idx, "age"] = "adult"
dt.loc[old_idx, "age"] = "old"

# %%
dt.head(10)
# Out:
#      class     sex    age alive
# 0    Third    male  adult    no
# 1    First  female  adult   yes
# 2    Third  female  adult   yes
# 3    First  female  adult   yes
# 4    Third    male  adult    no
# 6    First    male  adult    no
# 7    Third    male  child    no
# 8    Third  female  adult   yes
# 9   Second  female  child   yes
# 10   Third  female  child   yes

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting apyori
#   Downloading apyori-1.1.2.tar.gz (8.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: apyori
#   Building wheel for apyori (setup.py) ... done
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5976 sha256=0a9383c82c25e531b56df102fb3f538c807c7ea9ecb55c007f5449e0ae2d2e1a
#   Stored in directory: /root/.cache/pip/wheels/32/2a/54/10c595515f385f3726642b10c60bf788029e8f3a1323e3913a
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.2

# %%
from apyori import apriori

records = []
for i in range(len(dt)):
    records.append([str(dt.values[i,j]) for j in range(0, len(dt.columns))])
    
records
# Out:
# [['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'old', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Second', 'male', 'child', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Second', 'male', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'old', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'old', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'child', 'yes'],
#  ['First', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'child', 'yes'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'old', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'old', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'child', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'old', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['First', 'male', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['First', 'male', 'old', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Second', 'male', 'old', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'old', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['First', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'old', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'child', 'yes'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'child', 'no'],
#  ['Second', 'male', 'child', 'yes'],
#  ['First', 'female', 'old', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Second', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['Third', 'male', 'old', 'no'],
#  ['Third', 'female', 'child', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['Second', 'female', 'adult', 'no'],
#  ['Third', 'female', 'child', 'yes'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['First', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'female', 'child', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'male', 'child', 'no'],
#  ['First', 'female', 'adult', 'yes'],
#  ['Second', 'female', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['Third', 'male', 'adult', 'no'],
#  ['Third', 'female', 'adult', 'no'],
#  ['Second', 'male', 'adult', 'no'],
#  ['First', 'female', 'child', 'yes'],
#  ['First', 'male', 'adult', 'yes'],
#  ['Third', 'male', 'adult', 'no']]

# %%
association_rules = apriori(records, min_support=0.005, min_confidence=0.8)
association_results = list(association_rules)

association_results[1]

# RelationRecord(
# items=frozenset({'male', 'old'}), 
# support=0.03081232492997199, 
# ordered_statistics=[OrderedStatistic(items_base=frozenset({'old'}), 
# items_add=frozenset({'male'}), 
# confidence=0.8461538461538461, 
# lift=1.3336729495669895)])
# Out:
# RelationRecord(items=frozenset({'old', 'male'}), support=0.03081232492997199, ordered_statistics=[OrderedStatistic(items_base=frozenset({'old'}), items_add=frozenset({'male'}), confidence=0.8461538461538461, lift=1.3336729495669895)])

# %%
rules = []
for results in association_results:
    supp = results.support
    for orders in results.ordered_statistics:
        if(orders.items_add in [{'yes'},{'no'}]):
            conf = orders.confidence
            lift = orders.lift
            hypo = orders.items_base
            conc = orders.items_add
            rules.append([hypo,conc,supp,conf,lift])

rules[:5]
# Out:
# [[frozenset({'First', 'child'}),
#   frozenset({'yes'}),
#   0.023809523809523808,
#   0.8095238095238095,
#   1.993103448275862],
#  [frozenset({'First', 'female'}),
#   frozenset({'yes'}),
#   0.11484593837535013,
#   0.9647058823529412,
#   2.3751724137931034],
#  [frozenset({'Second', 'female'}),
#   frozenset({'yes'}),
#   0.09523809523809523,
#   0.9189189189189189,
#   2.262441752096924],
#  [frozenset({'Second', 'male'}),
#   frozenset({'no'}),
#   0.11764705882352941,
#   0.8484848484848484,
#   1.4288164665523155],
#  [frozenset({'Third', 'adult'}),
#   frozenset({'no'}),
#   0.27170868347338933,
#   0.8016528925619834,
#   1.3499532200218305]]

# %%
labels=["hypothesis","conclusion","support","confidence","lift"]
rules_dataframe = pd.DataFrame.from_records(rules, columns=labels)

rules_dataframe_sort = rules_dataframe.sort_values(["lift"], ascending=[False])
rules_dataframe_sort = rules_dataframe_sort.reset_index(drop = True)
rules_dataframe_sort
# Out:
#                  hypothesis conclusion   support  confidence      lift
# 0             (female, old)      (yes)  0.005602    1.000000  2.462069
# 1   (female, child, Second)      (yes)  0.022409    1.000000  2.462069
# 2    (adult, female, First)      (yes)  0.092437    0.970588  2.389655
# 3           (female, First)      (yes)  0.114846    0.964706  2.375172
# 4    (female, child, First)      (yes)  0.018207    0.928571  2.286207
# 5          (female, Second)      (yes)  0.095238    0.918919  2.262442
# 6   (adult, female, Second)      (yes)  0.072829    0.896552  2.207372
# 7            (child, First)      (yes)  0.023810    0.809524  1.993103
# 8        (Third, old, male)       (no)  0.005602    1.000000  1.683962
# 9     (adult, male, Second)       (no)  0.100840    0.947368  1.595333
# 10              (old, male)       (no)  0.026611    0.863636  1.454331
# 11     (adult, Third, male)       (no)  0.224090    0.860215  1.448570
# 12       (old, male, First)       (no)  0.016807    0.857143  1.443396
# 13            (Third, male)       (no)  0.301120    0.849802  1.431035
# 14           (male, Second)       (no)  0.117647    0.848485  1.428816
# 15            (adult, male)       (no)  0.389356    0.812865  1.368835
# 16     (Third, male, child)       (no)  0.071429    0.809524  1.363208
# 17           (adult, Third)       (no)  0.271709    0.801653  1.349953
